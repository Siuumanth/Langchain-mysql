# %%
import pandas as pd
# Out:
# The kernel failed to start as the Python Environment 'Langchain-mysql (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
from langchain_ollama.llms import OllamaLLM
from langchain_core.prompts import PromptTemplate

model = OllamaLLM(model="llama3.2")
# Out:
# The kernel failed to start as the Python Environment 'Langchain-mysql (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
print("sds")
# Out:
# sds
